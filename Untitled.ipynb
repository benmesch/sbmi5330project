# %% [markdown]
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE4170
#
#
# GEO has an integrated R script generator, so I installed R for Jupyter on my Mac (I already had R and Jupyter Notebooks, for Python, so it was pretty quick to do so:
#
# * http://www.storybench.org/install-r-jupyter-notebook/
# * https://medium.com/@kyleake/how-to-install-r-in-jupyter-with-irkernel-in-3-steps-917519326e41
# * https://stackoverflow.com/questions/39008069/r-and-python-in-one-jupyter-notebook
# * https://bioconductor.org/packages/release/bioc/html/Biobase.html
# * https://www.bioconductor.org/packages/release/bioc/html/GEOquery.html

# %% [markdown]
# First few lines of the GEO2R script, from GEO, involve loading R packages. In terminal, I had to install these packages in my conda environment before they would load here:

# %%
suppressMessages(library(limma))

# %%
system("conda env list", intern=TRUE)
# Out:
# [1] "# conda environments:"
# [2] "#"
# [3] "base                     /miniconda3"
# [4] "sbmi5330                 /miniconda3/envs/sbmi5330"
# [5] "test-cf-r             *  /miniconda3/envs/test-cf-r"
# [6] ""

# %%
system("conda list", intern=TRUE)
# Out:
#   [1] "# packages in environment at /miniconda3/envs/test-cf-r:"
#   [2] "#"
#   [3] "# Name                    Version                   Build  Channel"
#   [4] "_r-mutex                  1.0.0               anacondar_1  "
#   [5] "appnope                   0.1.0                    py37_0  "
#   [6] "attrs                     19.1.0                   py37_1  "
#   [7] "backcall                  0.1.0                    py37_0  "
#   [8] "bleach                    3.1.0                    py37_0  "
#   [9] "bwidget                   1.9.11                        1  "
#  [10] "bzip2                     1.0.6             h1de35cc_1002    conda-forge"
#  [11] "ca-certificates           2019.1.23                     0  "
#  [12] "cairo                     1.14.12           h9d4d9ac_1005    conda-forge"
#  [13] "cctools                   895                  h7512d6f_0    conda-forge"
#  [14] "certifi                   2019.3.9                 py37_0  "
#  [15] "clang                     4.0.1                h662ec87_0    conda-forge"
#  [16] "clang_osx-64              4.0.1               h1ce6c1d_11  "
#  [17] "clangxx                   4.0.1                hc9b4283_0  "
#  [18] "clangxx_osx-64            4.0.1               h22b1bf0_11  "
#  [19] "compiler-rt               4.0.1                h5487866_0    conda-forge"
#  [20] "curl                      7.64.1               h22ea746_0    conda-forge"
#  [21] "dbus                      1.13.6               h90a0687_0  "
#  [22] "decorator                 4.4.0                    py37_1  "
#  [23] "defusedxml                0.5.0                    py37_1  "
#  [24] "entrypoints               0.3                      py37_0  "
#  [25] "expat                     2.2.6                h0a44026_0  "
#  [26] "fontconfig                2.13.1            h1027ab8_1000    conda-forge"
#  [27] "freetype                  2.10.0               h24853df_0    conda-forge"
#  [28] "gettext                   0.19.8.1          h46ab8bc_1002    conda-forge"
#  [29] "gfortran_osx-64           4.8.5                h22b1bf0_8    conda-forge"
#  [30] "glib                      2.56.2            h67dad55_1001    conda-forge"
#  [31] "graphite2                 1.3.13            h2098e52_1000    conda-forge"
#  [32] "harfbuzz                  1.9.0             h9889186_1001    conda-forge"
#  [33] "icu                       58.2              h0a44026_1000    conda-forge"
#  [34] "ipykernel                 5.1.0            py37h39e3cac_0  "
#  [35] "ipython                   7.4.0            py37h39e3cac_0  "
#  [36] "ipython_genutils          0.2.0                    py37_0  "
#  [37] "ipywidgets                7.4.2                    py37_0  "
#  [38] "jedi                      0.13.3                   py37_0  "
#  [39] "jinja2                    2.10                     py37_0  "
#  [40] "jpeg                      9c                h1de35cc_1001    conda-forge"
#  [41] "jsonschema                3.0.1                    py37_0  "
#  [42] "jupyter                   1.0.0                    py37_7  "
#  [43] "jupyter_client            5.2.4                    py37_0  "
#  [44] "jupyter_console           6.0.0                    py37_0  "
#  [45] "jupyter_core              4.4.0                    py37_0  "
#  [46] "krb5                      1.16.3            hcfa6398_1001    conda-forge"
#  [47] "ld64                      274.2                h7c2db76_0    conda-forge"
#  [48] "libcurl                   7.64.1               h16faf7d_0    conda-forge"
#  [49] "libcxx                    4.0.1                h579ed51_0  "
#  [50] "libcxxabi                 4.0.1                hebd6815_0  "
#  [51] "libedit                   3.1.20170329      hcfe32e1_1001    conda-forge"
#  [52] "libffi                    3.2.1             h6de7cb9_1006    conda-forge"
#  [53] "libgfortran               3.0.1                         0    conda-forge"
#  [54] "libiconv                  1.15              h01d97ff_1005    conda-forge"
#  [55] "libpng                    1.6.36            ha441bb4_1000    conda-forge"
#  [56] "libsodium                 1.0.16               h3efe00b_0  "
#  [57] "libssh2                   1.8.2                hcdc9a53_1    conda-forge"
#  [58] "libtiff                   4.0.10            h79f4b77_1001    conda-forge"
#  [59] "libxml2                   2.9.8             hf14e9c8_1005    conda-forge"
#  [60] "llvm                      4.0.1                hc748206_0    conda-forge"
#  [61] "llvm-lto-tapi             4.0.1                h6701bc3_0    conda-forge"
#  [62] "llvm-openmp               4.0.1                hcfea43d_1  "
#  [63] "make                      4.2.1             h1de35cc_2004    conda-forge"
#  [64] "markupsafe                1.1.1            py37h1de35cc_0  "
#  [65] "mistune                   0.8.4            py37h1de35cc_0  "
#  [66] "nbconvert                 5.4.1                    py37_3  "
#  [67] "nbformat                  4.4.0                    py37_0  "
#  [68] "ncurses                   6.1               h0a44026_1002    conda-forge"
#  [69] "notebook                  5.7.6                    py37_0  "
#  [70] "openssl                   1.1.1b               h1de35cc_1  "
#  [71] "pandoc                    2.2.3.2                       0  "
#  [72] "pandocfilters             1.4.2                    py37_1  "
#  [73] "pango                     1.40.14           h57a785b_1003    conda-forge"
#  [74] "parso                     0.3.4                    py37_0  "
#  [75] "pcre                      8.41              h0a44026_1003    conda-forge"
#  [76] "pexpect                   4.6.0                    py37_0  "
#  [77] "pickleshare               0.7.5                    py37_0  "
#  [78] "pip                       19.0.3                   py37_0  "
#  [79] "pixman                    0.34.0            h1de35cc_1003    conda-forge"
#  [80] "prometheus_client         0.6.0                    py37_0  "
#  [81] "prompt_toolkit            2.0.9                    py37_0  "
#  [82] "ptyprocess                0.6.0                    py37_0  "
#  [83] "pygments                  2.3.1                    py37_0  "
#  [84] "pyqt                      5.9.2            py37h655552a_2  "
#  [85] "pyrsistent                0.14.11          py37h1de35cc_0  "
#  [86] "python                    3.7.2                haf84260_0  "
#  [87] "python-dateutil           2.8.0                    py37_0  "
#  [88] "pyzmq                     17.1.2           py37h1de35cc_0  "
#  [89] "qt                        5.9.7                h468cd18_1  "
#  [90] "qtconsole                 4.4.3                    py37_0  "
#  [91] "r-assertthat              0.2.0            r351hf348343_0  "
#  [92] "r-base                    3.5.1             he1ce5cd_1005    conda-forge"
#  [93] "r-base64enc               0.1_3            r351h6402f54_4  "
#  [94] "r-bh                      1.66.0_1         r351hf348343_0  "
#  [95] "r-bindr                   0.1.1            r351hf348343_0  "
#  [96] "r-bindrcpp                0.2.2            r351h32998d9_0  "
#  [97] "r-cli                     1.0.0            r351h6115d3f_0  "
#  [98] "r-crayon                  1.3.4            r351hf348343_0  "
#  [99] "r-curl                    3.2              r351h6402f54_0  "
# [100] "r-digest                  0.6.15           r351h6402f54_0  "
# [101] "r-dplyr                   0.7.6            r351h32998d9_0  "
# [102] "r-evaluate                0.11             r351hf348343_0  "
# [103] "r-fansi                   0.2.3            r351h6402f54_0  "
# [104] "r-glue                    1.3.0            r351h6402f54_0  "
# [105] "r-htmltools               0.3.6            r351h32998d9_0  "
# [106] "r-httr                    1.3.1            r351hf348343_0  "
# [107] "r-irdisplay               0.5.0            r351hf348343_0  "
# [108] "r-irkernel                0.8.12                   r351_0  "
# [109] "r-jsonlite                1.5              r351h6402f54_0  "
# [110] "r-magrittr                1.5              r351hf348343_4  "
# [111] "r-mime                    0.5              r351h6402f54_0  "
# [112] "r-openssl                 1.0.2            r351h46e59ec_1  "
# [113] "r-pbdzmq                  0.3_3            r351h32998d9_0  "
# [114] "r-pillar                  1.3.0            r351hf348343_0  "
# [115] "r-pkgconfig               2.0.1            r351hf348343_0  "
# [116] "r-plogr                   0.2.0            r351hf348343_0  "
# [117] "r-purrr                   0.2.5            r351h6402f54_0  "
# [118] "r-r6                      2.2.2            r351hf348343_0  "
# [119] "r-rcpp                    0.12.18          r351h32998d9_0  "
# [120] "r-repr                    0.15.0           r351hf348343_0  "
# [121] "r-rlang                   0.2.1            r351h6402f54_0  "
# [122] "r-stringi                 1.2.4            r351h32998d9_0  "
# [123] "r-stringr                 1.3.1            r351hf348343_0  "
# [124] "r-tibble                  1.4.2            r351h6402f54_0  "
# [125] "r-tidyr                   0.8.1            r351h32998d9_0  "
# [126] "r-tidyselect              0.2.4            r351h32998d9_0  "
# [127] "r-utf8                    1.1.4            r351h6402f54_0  "
# [128] "r-uuid                    0.1_2            r351h6402f54_4  "
# [129] "readline                  7.0               hcfe32e1_1001    conda-forge"
# [130] "send2trash                1.5.0                    py37_0  "
# [131] "setuptools                40.8.0                   py37_0  "
# [132] "sip                       4.19.8           py37h0a44026_0  "
# [133] "six                       1.12.0                   py37_0  "
# [134] "sqlite                    3.26.0               ha441bb4_0  "
# [135] "terminado                 0.8.1                    py37_1  "
# [136] "testpath                  0.4.2                    py37_0  "
# [137] "tk                        8.6.9             ha441bb4_1001    conda-forge"
# [138] "tktable                   2.10                 h1de35cc_0  "
# [139] "tornado                   6.0.2            py37h1de35cc_0  "
# [140] "traitlets                 4.3.2                    py37_0  "
# [141] "wcwidth                   0.1.7                    py37_0  "
# [142] "webencodings              0.5.1                    py37_1  "
# [143] "wheel                     0.33.1                   py37_0  "
# [144] "widgetsnbextension        3.4.2                    py37_0  "
# [145] "xz                        5.2.4             h1de35cc_1001    conda-forge"
# [146] "zeromq                    4.2.5                h0a44026_1  "
# [147] "zlib                      1.2.11            h1de35cc_1004    conda-forge"

# %%
%R installed.packages()
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:1: unexpected input
# 1: %R installed.packages()
#     ^
# Traceback:

# %%
suppressMessages(library(GEOquery))
# Out:
# Error in library(GEOquery): there is no package called ‘GEOquery’
# Traceback:
#
# 1. suppressMessages(library(GEOquery))
# 2. withCallingHandlers(expr, message = function(c) invokeRestart("muffleMessage"))
# 3. library(GEOquery)
# 4. stop(txt, domain = NA)

# %%
# Version info: R 3.2.3, Biobase 2.30.0, GEOquery 2.40.0, limma 3.26.8
# R scripts generated  Thu Mar 28 01:28:39 EDT 2019

################################################################
#   Differential expression analysis with limma
suppressMessages(library(Biobase))
suppressMessages(library("GEOquery"))
suppressMessages(library(limma))
# Out:
# Error in library("GEOquery"): there is no package called ‘GEOquery’
# Traceback:
#
# 1. suppressMessages(library("GEOquery"))
# 2. withCallingHandlers(expr, message = function(c) invokeRestart("muffleMessage"))
# 3. library("GEOquery")
# 4. stop(txt, domain = NA)

# %%
# load series and platform data from GEO
gset <- getGEO("GSE4170", GSEMatrix =TRUE, AnnotGPL=TRUE) #Radich 2006
if (length(gset) > 1) idx <- grep("GPL2029", attr(gset, "names")) else idx <- 1
gset <- gset[[idx]]

# %% [markdown]
# In the web tool, marked the first 21 of 119 samples. The first 6 were labeled "cd" group, the next 15 labeled "ap" group. A third group, "bc" was created by not used for any samples.
#
# The tool limits users to only 10 groups, because it encodes them as single digit integers:

# %%
# make proper column names to match toptable 
fvarLabels(gset) <- make.names(fvarLabels(gset))

# group names for all samples
gsms <- paste0("000000111111111111111XXXXXXXXXXXXXXXXXXXXXXXXXXXXX",
        "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX",
        "XXXXXXXXXXXXXXXXXXX")
sml <- c() #initialize vector
for (i in 1:nchar(gsms)) { sml[i] <- substr(gsms,i,i) } #fill vector with the character 0-9 or an X

# eliminate samples marked as "X"
sel <- which(sml != "X")
sml <- sml[sel]
gset <- gset[ ,sel]

# %% [markdown]
#     Apply log transformation to the data: The GEO database accepts a variety of data value types, including logged and unlogged data. Limma expects data values to be in log space. To address this, GEO2R has an auto-detect feature that checks the values of selected Samples and automatically performs a log2 transformation on values determined not to be in log space. Alternatively, the user can select Yes to force log2 transformation, or No to override the auto-detect feature. The auto-detect feature only considers Sample values that have been assigned to a group, and applies the transformation in an all-or-none fashion.

# %%
# log2 transform
ex <- exprs(gset)
qx <- as.numeric(quantile(ex, c(0., 0.25, 0.5, 0.75, 0.99, 1.0), na.rm=T))
LogC <- (qx[5] > 100) ||
          (qx[6]-qx[1] > 50 && qx[2] > 0) ||
          (qx[2] > 0 && qx[2] < 1 && qx[4] > 1 && qx[4] < 2)
if (LogC) { ex[which(ex <= 0)] <- NaN
  exprs(gset) <- log2(ex) }

# set up the data and proceed with analysis
sml <- paste("G", sml, sep="")    # set group names
fl <- as.factor(sml)
gset$description <- fl
design <- model.matrix(~ description + 0, gset)
colnames(design) <- levels(fl)
fit <- lmFit(gset, design)
cont.matrix <- makeContrasts(G1-G0, levels=design)
fit2 <- contrasts.fit(fit, cont.matrix)
fit2 <- eBayes(fit2, 0.01)
tT <- topTable(fit2, adjust="fdr", sort.by="B", number=250)

#tT <- subset(tT, select=c("ID","adj.P.Val","P.Value","F","Gene.symbol","Gene.title")) 
#reselected columns, to include gene id and GO function...
tT <- subset(tT, select=c("ID","adj.P.Val","P.Value","F","Gene.symbol","Gene.title","Gene.ID","GO.Function"))
write.table(tT, file=stdout(), row.names=F, sep="\t")

# %% [markdown]
# Used a 2nd tab on the GEO2R tool to create a box plot. I think it added a 2nd half to the script for this plot as a result:

# %%
################################################################
#   Boxplot for selected GEO samples
library(Biobase)
library(GEOquery)

# load series and platform data from GEO

gset <- getGEO("GSE4170", GSEMatrix =TRUE, getGPL=FALSE)
if (length(gset) > 1) idx <- grep("GPL2029", attr(gset, "names")) else idx <- 1
gset <- gset[[idx]]

# group names for all samples in a series
gsms <- paste0("000000111111111111111XXXXXXXXXXXXXXXXXXXXXXXXXXXXX",
        "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX",
        "XXXXXXXXXXXXXXXXXXX")
sml <- c()
for (i in 1:nchar(gsms)) { sml[i] <- substr(gsms,i,i) }
sml <- paste("G", sml, sep="")  set group names

# eliminate samples marked as "X"
sel <- which(sml != "X")
sml <- sml[sel]
gset <- gset[ ,sel]

# order samples by group
ex <- exprs(gset)[ , order(sml)]
sml <- sml[order(sml)]
fl <- as.factor(sml)
labels <- c("cd","ap","bc")

# set parameters and draw the plot
palette(c("#dfeaf4","#f4dfdf","#f2cb98", "#AABBCC"))
dev.new(width=4+dim(gset)[[2]]/5, height=6)
par(mar=c(2+round(max(nchar(sampleNames(gset)))/2),4,2,1))
title <- paste ("GSE4170", '/', annotation(gset), " selected samples", sep ='')
boxplot(ex, boxwex=0.6, notch=T, main=title, outline=FALSE, las=2, col=fl)
legend("topleft", labels, fill=palette(), bty="n")
